# %% [markdown]
# #Import library

# %%
## single frame analysis: whether there are large spatta?
import cv2
from IPython import display
from matplotlib import pyplot as plt
import time
from numpy import dtype,uint8
import scipy.ndimage as ndimage
import glob
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # subtract imgs

# %%
import os
import glob 

def subtractImgs(division,date,speed=100):
    rootDir = r"C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\{date}\IR1000_B500_S{speed}\{div}\crop".format(date=date,speed=speed,div=division)
    saveDir = os.path.join(rootDir,"subtraction")
    if not os.path.exists(saveDir):
        os.makedirs(saveDir)
    #フォルダに存在するファイルを取得する、0001.jpg~0005.jpg→{}/*.jpg
    src_files=glob.glob("{}/*.jpg".format(rootDir))
    src_files.sort()
    count = 0
    for i,file in enumerate(src_files): #index,components=enumerate(file)
        if i%400 == 0:
            print(i,"::",file)
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            print(imgIndex)

        if i == 0:
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            oldImg = cv2.imread(file,0)
        else:
            if count==2:
                break
            imgIndex = int((file.split("\\")[-1]).split(".")[0])
            img = cv2.imread(file,0)
            imgSubtract = cv2.absdiff(img,oldImg)
            #print(imgSubtract)
            cv2.imwrite(os.path.join(saveDir,f"{imgIndex:03d}.jpg"),imgSubtract)
            oldImg = img.copy()

# %% [markdown]
# ## speed=100 mm/sec

# %%
date = "20230823"
speed=100
for i in range(13,43):
    if i!=17:
        subtractImgs(division=i,date=date,speed=speed)
# Out:
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\22\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\22\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\22\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\23\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\24\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\25\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\26\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\27\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\28\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\29\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\30\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\31\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\32\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\33\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\34\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\35\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\36\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\37\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\38\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\39\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\40\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\41\crop\451.jpg
# 451
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\001.jpg
# 1
# 50 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\051.jpg
# 51
# 100 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\101.jpg
# 101
# 150 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\151.jpg
# 151
# 200 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\201.jpg
# 201
# 250 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\251.jpg
# 251
# 300 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\301.jpg
# 301
# 350 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\351.jpg
# 351
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\401.jpg
# 401
# 450 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100\42\crop\451.jpg
# 451

# %% [markdown]
# ## speed= 200 mm/sec

# %%
date = "20230823"
speed=200
for i in range(51,81):
    if i!=17:
        subtractImgs(division=i,date=date,speed=speed)
# Out:
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\51\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\51\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\52\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\52\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\53\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\53\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\54\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\54\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\55\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\55\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\56\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\56\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\57\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\57\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\58\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\58\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\59\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\59\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\60\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\60\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\61\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\61\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\62\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\62\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\63\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\63\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\64\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\64\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\65\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\65\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\66\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\66\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\67\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\67\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\68\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\68\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\69\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\69\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\70\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\70\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\71\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\71\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\72\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\72\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\73\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\73\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\74\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\74\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\75\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\75\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\76\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\76\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\77\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\77\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\78\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\78\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\79\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\79\crop\401.jpg
# 401
# 0 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\80\crop\001.jpg
# 1
# 400 :: C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200\80\crop\401.jpg
# 401

# %% [markdown]
# # Class

# %%
import numpy as np
import os
import csv
import random

class Dataset():
  def __init__(self,start_index,x_patch = 3, y_patch = 3, height = 80,width = 80,speed=100,
                date = "20220401",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20220401',
                dir_concatImg = "concat_vit_subtraction"
              ):
    self.start_index=start_index
    #num of patches
    self.x_patch = x_patch
    self.y_patch = y_patch  
    #size for 1 patch
    self.height = height
    self.width = width
    #size for concatenated img
    self.H = x_patch*height
    self.W = y_patch*width
    #date of dataset
    self.date = date
    #img src directory
    self.src_dir = src_dir
    #directory for concat img
    self.dir_concatImg = dir_concatImg
    self.speed=speed
    #load spatter labels from .txt file
    #load spatter labels from .txt fil   
    if speed==100:
        dir = r'C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, {speed}mm_s\video'.format(speed=speed)
        self.spatter_data_13 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(13)), dtype='int').tolist()
        self.spatter_data_14 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(14)), dtype='int').tolist()
        self.spatter_data_15 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(15)), dtype='int').tolist()
        self.spatter_data_16 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(16)), dtype='int').tolist()
        #self.spatter_data_17 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(17)), dtype='int').tolist()
        self.spatter_data_18 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(18)), dtype='int').tolist()
        self.spatter_data_19 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(19)), dtype='int').tolist()
        self.spatter_data_20 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(20)), dtype='int').tolist()
        self.spatter_data_21 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(21)), dtype='int').tolist()
        self.spatter_data_22 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(22)), dtype='int').tolist()
        self.spatter_data_23 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(23)), dtype='int').tolist()
        self.spatter_data_24 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(24)), dtype='int').tolist()
        self.spatter_data_25 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(25)), dtype='int').tolist()
        self.spatter_data_26 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(26)), dtype='int').tolist()
        self.spatter_data_27 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(27)), dtype='int').tolist()
        self.spatter_data_28 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(28)), dtype='int').tolist()
        self.spatter_data_29 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(29)), dtype='int').tolist()
        self.spatter_data_30 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(30)), dtype='int').tolist()
        self.spatter_data_31 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(31)), dtype='int').tolist()
        self.spatter_data_32 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(32)), dtype='int').tolist()
        self.spatter_data_33 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(33)), dtype='int').tolist()
        self.spatter_data_34 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(34)), dtype='int').tolist()
        self.spatter_data_35 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(35)), dtype='int').tolist()
        self.spatter_data_36 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(36)), dtype='int').tolist()
        self.spatter_data_37 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(37)), dtype='int').tolist()
        self.spatter_data_38 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(38)), dtype='int').tolist()
        self.spatter_data_39 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(39)), dtype='int').tolist()
        self.spatter_data_40 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(40)), dtype='int').tolist()
        self.spatter_data_41 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(41)), dtype='int').tolist()
        self.spatter_data_42 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(42)), dtype='int').tolist()
    elif speed==200:
      dir = r'C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, {speed}mm_s\video'.format(speed=speed)
      self.spatter_data_51 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(51)), dtype='int').tolist()
      self.spatter_data_52 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(52)), dtype='int').tolist()
      self.spatter_data_53 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(53)), dtype='int').tolist()
      self.spatter_data_54 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(54)), dtype='int').tolist()
      self.spatter_data_55 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(55)), dtype='int').tolist()
      self.spatter_data_56 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(56)), dtype='int').tolist()
      self.spatter_data_57 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(57)), dtype='int').tolist()
      self.spatter_data_58 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(58)), dtype='int').tolist()
      self.spatter_data_59 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(59)), dtype='int').tolist()
      self.spatter_data_60 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(60)), dtype='int').tolist()
      self.spatter_data_61 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(61)), dtype='int').tolist()
      self.spatter_data_62 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(62)), dtype='int').tolist()
      self.spatter_data_63 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(63)), dtype='int').tolist()
      self.spatter_data_64 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(64)), dtype='int').tolist()
      self.spatter_data_65 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(65)), dtype='int').tolist()
      self.spatter_data_66 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(66)), dtype='int').tolist()
      self.spatter_data_67 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(67)), dtype='int').tolist()
      self.spatter_data_68 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(68)), dtype='int').tolist()
      self.spatter_data_69 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(69)), dtype='int').tolist()
      self.spatter_data_70 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(70)), dtype='int').tolist()
      self.spatter_data_71 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(71)), dtype='int').tolist()
      self.spatter_data_72 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(72)), dtype='int').tolist()
      self.spatter_data_73 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(73)), dtype='int').tolist()
      self.spatter_data_74 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(74)), dtype='int').tolist()
      self.spatter_data_75 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(75)), dtype='int').tolist()
      self.spatter_data_76 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(76)), dtype='int').tolist()
      self.spatter_data_77 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(77)), dtype='int').tolist()
      self.spatter_data_78 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(78)), dtype='int').tolist()
      self.spatter_data_79 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(79)), dtype='int').tolist()
      self.spatter_data_80 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(80)), dtype='int').tolist()

  def concatImg(self,index,src_img_dir,save_dir,INVERSE = False):
      """concatenate images
      Args:
        index: index for spatter frame, so index is the latest index in 9 frames, ie. index, index-1,index-2,..., index-8
        src_img_dir : source directory of cropped imgs
        save_dir : save dir for concatenate images
        x_patch, y_patch : number of patches in x and y axis
        INVERSE : patch order. If INVERSE is True, new to old is applied
      Return:
        file_path : path for concat img
        write concatenated images into designated directory
      """
      concat = np.zeros((self.H,self.W,1))
      for i in range(9):
          file = "{:03d}.jpg".format(index-i) #from new to old
          path = os.path.join(src_img_dir,file)
          img = cv2.imread(path)
          img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #gray scale
          img = np.expand_dims(np.array(img).astype("int32"),2) #add color channel : (height,width,1)
          #new to old
          if INVERSE:
              row = i//3
              column = i%3
              concat[self.height*row:self.height*(row+1),self.width*column:self.width*(column+1),:] = img
          #old to new
          else:
              row =  (self.x_patch-1) - i//3
              column = (self.y_patch-1) - i%3
              concat[self.height*row:self.height*(row+1),self.width*column:self.width*(column+1),:] = img
      file_path = os.path.join(save_dir,f"{index:03d}.jpg")
      cv2.imwrite(file_path,concat)
      return file_path

  def checkImg(self,file_path):
    """check whether laser process has started

    Args:
        file_path (str): img file path
    """
    img = cv2.imread(file_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    gray = gray
    ret,thresh = cv2.threshold(gray,40,255,cv2.THRESH_BINARY)
    #find contours
    contours, hierarchy = cv2.findContours(np.array(thresh,dtype=uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    Area = []
    #detect laser area
    if (bool(contours)==True):
      #面積(px*px)
      for j in contours:
        area = cv2.contourArea(j)
        Area.append(area)

      if Area:
        area_max = np.max(Area)
        if area_max > 9:
           ret = True
           return ret
        else:
           ret = False
           return ret
      else:
         ret = False
         return ret
      
  # adjust the number of no spatter below 51
  def make(self,filename,filename_test,div,sec):
    #フォルダに存在するファイルを取得する、0001.jpg~0005.jpg→{}/*.jpg
    
    #spatter label 
    if self.speed==100:
       spatter = [self.spatter_data_13,self.spatter_data_14,self.spatter_data_15,
                  self.spatter_data_16,[],self.spatter_data_18,self.spatter_data_19,
                  [self.spatter_data_20],self.spatter_data_21,[self.spatter_data_22],
                  self.spatter_data_23,self.spatter_data_24,self.spatter_data_25,
                  self.spatter_data_26,self.spatter_data_27,[self.spatter_data_28],
                  self.spatter_data_29,self.spatter_data_30,self.spatter_data_31,
                  self.spatter_data_32,self.spatter_data_33,self.spatter_data_34,
                  self.spatter_data_35,[self.spatter_data_36],self.spatter_data_37,
                  self.spatter_data_38,self.spatter_data_39,[self.spatter_data_40],
                  [self.spatter_data_41],self.spatter_data_42
                  ]
    elif self.speed == 200:
      spatter = [[self.spatter_data_51],self.spatter_data_52,[self.spatter_data_53],
                  self.spatter_data_54,self.spatter_data_55,self.spatter_data_56,
                  [self.spatter_data_57],self.spatter_data_58,[self.spatter_data_59],
                  self.spatter_data_60,[self.spatter_data_61],self.spatter_data_62,
                  self.spatter_data_63,self.spatter_data_64,self.spatter_data_65,
                  [self.spatter_data_66],self.spatter_data_67,self.spatter_data_68,
                  [self.spatter_data_69],self.spatter_data_70,self.spatter_data_71,
                  self.spatter_data_72,[self.spatter_data_73],[self.spatter_data_74],
                  self.spatter_data_75,self.spatter_data_76,[self.spatter_data_77],
                  [self.spatter_data_78],self.spatter_data_79,[self.spatter_data_80]
                  ]
    
    #set src img directory
    src_img_dir = os.path.join(self.src_dir,"{}\crop\subtraction".format(div))
    #make save directory
    save_dir= os.path.join(self.src_dir,"{}\{}".format(div,self.dir_concatImg))
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)

    #spatter count
    count_spatter = 0
    count_nonspatter = 0
    #get num of file in a directory
    num_photo = sum(os.path.isfile(os.path.join(src_img_dir,name)) for name in os.listdir(src_img_dir))
    print("{}-{} progressing :: {}".format(div,sec,num_photo))
    #make dataset
    for i in range(10,num_photo-10):
      file_path = os.path.join(src_img_dir,f"{i:03d}.jpg")
      ret = self.checkImg(file_path=file_path)
      #laser welding has started
      if ret :
        #spater frame
        if (((i+10) in spatter[div-self.start_index]) or ((i+9) in spatter[div-self.start_index]) or ((i+8) in spatter[div-self.start_index]) or 
            ((i+7) in spatter[div-self.start_index]) or ((i+6) in spatter[div-self.start_index]) or ((i+5) in spatter[div-self.start_index]) or 
            ((i+4) in spatter[div-self.start_index]) or ((i+3) in spatter[div-self.start_index]) or ((i+2) in spatter[div-self.start_index])):  
          #whether spatter frame is included in input frame
          if ((i not in spatter[div-self.start_index]) and ((i-1) not in spatter[div-self.start_index]) and ((i-2) not in spatter[div-self.start_index]) and 
              ((i-3) not in spatter[div-self.start_index]) and ((i-4) not in spatter[div-self.start_index]) and ((i-5) not in spatter[div-self.start_index]) and 
            ((i-6) not in spatter[div-self.start_index]) and ((i-7) not in spatter[div-self.start_index]) and ((i-8) not in spatter[div-self.start_index]) and
            ((i-9) not in spatter[div-self.start_index])):
            #concatenate images
            file_path = self.concatImg(index=i,src_img_dir=src_img_dir,save_dir=save_dir,INVERSE = False)
            if random.random() >= 0.1: #85% is train data
              with open(filename,"a",newline='') as f:
                writer = csv.writer(f)
                writer.writerow([1,file_path])
            else:
              with open(filename_test,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([1,file_path])
            count_spatter += 1
        #non-spatter frame
        else:
          #whether spatter frame is included in input frame
          if ((i not in spatter[div-self.start_index]) and ((i-1) not in spatter[div-self.start_index]) and ((i-2) not in spatter[div-self.start_index]) and 
              ((i-3) not in spatter[div-self.start_index]) and ((i-4) not in spatter[div-self.start_index]) and ((i-5) not in spatter[div-self.start_index]) and 
              ((i-6) not in spatter[div-self.start_index]) and ((i-7) not in spatter[div-self.start_index]) and ((i-8) not in spatter[div-self.start_index]) and 
              ((i-9) not in spatter[div-self.start_index])) :
            #random function for variety of dataset
            if self.speed==100:
              threshold_nonSpatter=0.99
            elif self.speed==200:
              threshold_nonSpatter=0.975
            #random function for variety of dataset
            if random.random() >= threshold_nonSpatter:
              #concatenate images
              file_path = self.concatImg(index=i,src_img_dir=src_img_dir,save_dir=save_dir,INVERSE = False)
              if random.random() >= 0.1: #85% is train data
                with open(filename,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([0,file_path])
              else:
                with open(filename_test,"a",newline='') as f:
                  writer = csv.writer(f)
                  writer.writerow([0,file_path])
              count_nonspatter += 1
    print(f"Finished! Spatter :: {count_spatter}, Non-spatter :: {count_nonspatter}")

# %% [markdown]
# ## speed=100 mm/sec

# %%
import csv







#Initialize csv dataset?
INITIALIZE = True



#prepare csv files
file_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\csv\ViT'
filename=os.path.join(file_dir,"train_vitSubtraction_IR1000_B500_S100.csv")
filename_test=os.path.join(file_dir,"test_vitSubtraction_IR1000_B500_S100.csv")
#///////////////////
if INITIALIZE:
  #make csv file
  with open(filename,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

  with open(filename_test,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

# %%
START=13
dataset = Dataset(start_index=START,x_patch = 3, y_patch = 3, height = 80,width = 80,speed=100,
                date = "20230823",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S100',
                dir_concatImg = "concat_vitSubtraction"
                )

#make dataset one by one
for i in range(13,43):
  for j in range(1,2):
    if i!=17:
      dataset.make(filename=filename,filename_test=filename_test,div = i,sec = j)
# Out:
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:33: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\13_spatter.txt"
#   self.spatter_data_13 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(13)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:35: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\15_spatter.txt"
#   self.spatter_data_15 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(15)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:36: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\16_spatter.txt"
#   self.spatter_data_16 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(16)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:38: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\18_spatter.txt"
#   self.spatter_data_18 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(18)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:39: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\19_spatter.txt"
#   self.spatter_data_19 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(19)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:41: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\21_spatter.txt"
#   self.spatter_data_21 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(21)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:43: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\23_spatter.txt"
#   self.spatter_data_23 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(23)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:45: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\25_spatter.txt"
#   self.spatter_data_25 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(25)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:46: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\26_spatter.txt"
#   self.spatter_data_26 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(26)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:50: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\30_spatter.txt"
#   self.spatter_data_30 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(30)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:52: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\32_spatter.txt"
#   self.spatter_data_32 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(32)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:54: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\34_spatter.txt"
#   self.spatter_data_34 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(34)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:57: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\37_spatter.txt"
#   self.spatter_data_37 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(37)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:59: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 100mm_s\video\39_spatter.txt"
#   self.spatter_data_39 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(39)), dtype='int').tolist()
# 13-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 1
# 14-1 progressing :: 497
# Finished! Spatter :: 4, Non-spatter :: 2
# 15-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 4
# 16-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 3
# 18-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 1
# 19-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 4
# 20-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 2
# 21-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 0
# 22-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 1
# 23-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 1
# 24-1 progressing :: 496
# Finished! Spatter :: 3, Non-spatter :: 5
# 25-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 3
# 26-1 progressing :: 494
# Finished! Spatter :: 0, Non-spatter :: 1
# 27-1 progressing :: 494
# Finished! Spatter :: 8, Non-spatter :: 2
# 28-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 4
# 29-1 progressing :: 494
# Finished! Spatter :: 6, Non-spatter :: 2
# 30-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 0
# 31-1 progressing :: 496
# Finished! Spatter :: 15, Non-spatter :: 1
# 32-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 6
# 33-1 progressing :: 497
# Finished! Spatter :: 4, Non-spatter :: 2
# 34-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 4
# 35-1 progressing :: 498
# Finished! Spatter :: 12, Non-spatter :: 1
# 36-1 progressing :: 496
# Finished! Spatter :: 2, Non-spatter :: 2
# 37-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 3
# 38-1 progressing :: 491
# Finished! Spatter :: 6, Non-spatter :: 2
# 39-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 2
# 40-1 progressing :: 496
# Finished! Spatter :: 6, Non-spatter :: 2
# 41-1 progressing :: 497
# Finished! Spatter :: 4, Non-spatter :: 0
# 42-1 progressing :: 496
# Finished! Spatter :: 8, Non-spatter :: 4

# %% [markdown]
# ## check dataset

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
labels_train = train[:,0]
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
labels_test = test[:,0]
print(test.shape)
def count_spatter(labels):
    count = 0
    for i in range(labels.shape[0]):
        if labels[i] == 1:
            count += 1
    print(f"Spatter/total : {count}/{labels.shape[0]}")

print("train data")
count_spatter(labels_train)
print("test data")
count_spatter(labels_test)
# Out:
# (124, 2)
# (19, 2)
# train data
# Spatter/total : 68/124
# test data
# Spatter/total : 10/19

# %% [markdown]
# ## speed=200 mm/sec

# %%
import csv







#Initialize csv dataset?
INITIALIZE = True



#prepare csv files
file_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\csv\ViT'
filename=os.path.join(file_dir,"train_vitSubtraction_IR1000_B500_S200.csv")
filename_test=os.path.join(file_dir,"test_vitSubtraction_IR1000_B500_S200.csv")
#///////////////////
if INITIALIZE:
  #make csv file
  with open(filename,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

  with open(filename_test,"w") as f:
    writer = csv.writer(f)
    writer.writerow(["Spatter","Path"])

# %%
START=51
dataset = Dataset(start_index=START,x_patch = 3, y_patch = 3, height = 80,width = 80,speed=200,
                date = "20230823",
                src_dir = r'C:\Users\Furukawa\Documents\TechAssistant\dataset\imgs\20230823\IR1000_B500_S200',
                dir_concatImg = "concat_vitSubtraction"
                )

#make dataset one by one
for i in range(51,81):
  for j in range(1,2):
      dataset.make(filename=filename,filename_test=filename_test,div = i,sec = j)
# Out:
# 51-1 progressing :: 498
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:68: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\54_spatter.txt"
#   self.spatter_data_54 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(54)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:69: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\55_spatter.txt"
#   self.spatter_data_55 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(55)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:72: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\58_spatter.txt"
#   self.spatter_data_58 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(58)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:74: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\60_spatter.txt"
#   self.spatter_data_60 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(60)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:76: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\62_spatter.txt"
#   self.spatter_data_62 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(62)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:78: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\64_spatter.txt"
#   self.spatter_data_64 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(64)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:79: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\65_spatter.txt"
#   self.spatter_data_65 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(65)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:81: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\67_spatter.txt"
#   self.spatter_data_67 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(67)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:82: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\68_spatter.txt"
#   self.spatter_data_68 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(68)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:84: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\70_spatter.txt"
#   self.spatter_data_70 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(70)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:85: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\71_spatter.txt"
#   self.spatter_data_71 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(71)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:86: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\72_spatter.txt"
#   self.spatter_data_72 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(72)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:90: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\76_spatter.txt"
#   self.spatter_data_76 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(76)), dtype='int').tolist()
# C:\Users\Furukawa\AppData\Local\Temp\ipykernel_16816\1877212371.py:93: UserWarning: loadtxt: input contained no data: "C:\Users\Furukawa\Documents\TechAssistant\Video\20230823_synchronized\IR_1000W, B_500W, 200mm_s\video\79_spatter.txt"
#   self.spatter_data_79 = np.loadtxt(os.path.join(dir,'{}_spatter.txt'.format(79)), dtype='int').tolist()
# Finished! Spatter :: 6, Non-spatter :: 3
# 52-1 progressing :: 496
# Finished! Spatter :: 10, Non-spatter :: 3
# 53-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 2
# 54-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 4
# 55-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 4
# 56-1 progressing :: 497
# Finished! Spatter :: 11, Non-spatter :: 0
# 57-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 3
# 58-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 2
# 59-1 progressing :: 498
# Finished! Spatter :: 6, Non-spatter :: 2
# 60-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 2
# 61-1 progressing :: 497
# Finished! Spatter :: 3, Non-spatter :: 3
# 62-1 progressing :: 495
# Finished! Spatter :: 0, Non-spatter :: 6
# 63-1 progressing :: 495
# Finished! Spatter :: 17, Non-spatter :: 0
# 64-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 5
# 65-1 progressing :: 496
# Finished! Spatter :: 0, Non-spatter :: 1
# 66-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 3
# 67-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 1
# 68-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 2
# 69-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 4
# 70-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 5
# 71-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 0
# 72-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 2
# 73-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 3
# 74-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 2
# 75-1 progressing :: 498
# Finished! Spatter :: 10, Non-spatter :: 2
# 76-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 2
# 77-1 progressing :: 498
# Finished! Spatter :: 0, Non-spatter :: 3
# 78-1 progressing :: 497
# Finished! Spatter :: 4, Non-spatter :: 6
# 79-1 progressing :: 497
# Finished! Spatter :: 0, Non-spatter :: 3
# 80-1 progressing :: 498
# Finished! Spatter :: 8, Non-spatter :: 5

# %%
import pandas as pd
file_train = pd.read_csv(filename)
train = file_train.values
labels_train = train[:,0]
print(train.shape)
file_test = pd.read_csv(filename_test)
test = file_test.values
labels_test = test[:,0]
print(test.shape)
def count_spatter(labels):
    count = 0
    for i in range(labels.shape[0]):
        if labels[i] == 1:
            count += 1
    print(f"Spatter/total : {count}/{labels.shape[0]}")

print("train data")
count_spatter(labels_train)
print("test data")
count_spatter(labels_test)
# Out:
# (138, 2)
# (20, 2)
# train data
# Spatter/total : 67/138
# test data
# Spatter/total : 8/20
